# %% [markdown]
# # Power Outage Prediction - Feature Engineering & Selection
# ## Creating and Selecting Predictive Features
#
# **Objective**: Engineer meaningful features from weather and temporal data, then select the most predictive ones.
#
# **Key Areas**:
# - Weather-based feature engineering
# - Temporal feature engineering
# - Geographic feature engineering
# - Feature importance analysis
# - Feature selection methods

# %%
# Setup and imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from sklearn.feature_selection import mutual_info_classif, SelectKBest, f_classif
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# Set style
plt.style.use('default')
sns.set_palette("husl")

# Load integrated dataset
def load_integrated_data():
    data_dir = Path("../../data/processed")
    integrated_file = data_dir / "integrated_dataset.csv"
    
    if integrated_file.exists():
        df = pd.read_csv(integrated_file)
        df['date'] = pd.to_datetime(df['date'])
        return df
    else:
        raise FileNotFoundError("Run data integration notebook first")

# Create output directory
output_dir = Path("../../notebooks/outputs/milestone_1/feature_analysis")
output_dir.mkdir(parents=True, exist_ok=True)

df = load_integrated_data()
print(f"Dataset loaded: {df.shape}")
print(f"Outage rate: {df['outage_occurred'].mean():.1%}")
print(f"Columns: {list(df.columns)}")
# Out:
# Dataset loaded: (3976135, 17)
# Outage rate: 46.3%
# Columns: ['fips_code', 'date', 'prcp', 'tmax', 'tmin', 'outage_occurred', 'customers_out', 'county', 'state', 'run_start_time', 'year', 'month', 'day_of_week', 'day_name', 'season', 'outage_hour', 'region']

# %% [markdown]
# ## Weather-Based Feature Engineering
# Create features based on visualization insights about weather patterns.

# %%
# Create weather-based features
df_features = df.copy()

# Temperature range and extremes
df_features['temp_range'] = df_features['tmax'] - df_features['tmin']
df_features['temp_avg'] = (df_features['tmax'] + df_features['tmin']) / 2

# Temperature extremes (based on percentiles from visualizations)
tmax_95 = df_features['tmax'].quantile(0.95)
tmin_5 = df_features['tmin'].quantile(0.05)
prcp_95 = df_features['prcp'].quantile(0.95)

df_features['extreme_hot'] = (df_features['tmax'] >= tmax_95).astype(int)
df_features['extreme_cold'] = (df_features['tmin'] <= tmin_5).astype(int)
df_features['heavy_precipitation'] = (df_features['prcp'] >= prcp_95).astype(int)

# Temperature bins (based on threshold analysis)
df_features['tmax_bin'] = pd.cut(df_features['tmax'], bins=10, labels=False)
df_features['tmin_bin'] = pd.cut(df_features['tmin'], bins=10, labels=False)

# Precipitation categories
df_features['prcp_category'] = pd.cut(
    df_features['prcp'], 
    bins=[0, 0.1, 5, 15, 50, np.inf], 
    labels=['none', 'light', 'moderate', 'heavy', 'extreme'],
    include_lowest=True
)
df_features['prcp_category'] = df_features['prcp_category'].astype(str)

# Weather stress indicators
df_features['temp_stress'] = (
    (df_features['tmax'] >= tmax_95) | 
    (df_features['tmin'] <= tmin_5)
).astype(int)

df_features['combined_extreme'] = (
    df_features['temp_stress'] & 
    df_features['heavy_precipitation']
).astype(int)

# Precipitation intensity (non-zero days only)
df_features['prcp_intensity'] = np.where(
    df_features['prcp'] > 0, 
    df_features['prcp'], 
    0
)
df_features['has_precipitation'] = (df_features['prcp'] > 0).astype(int)

print("Weather-based features created:")
weather_features = ['temp_range', 'temp_avg', 'extreme_hot', 'extreme_cold', 
                   'heavy_precipitation', 'tmax_bin', 'tmin_bin', 'prcp_category',
                   'temp_stress', 'combined_extreme', 'prcp_intensity', 'has_precipitation']
for feat in weather_features:
    print(f"  {feat}: {df_features[feat].dtype}")
# Out:
# Weather-based features created:
#   temp_range: float64
#   temp_avg: float64
#   extreme_hot: int64
#   extreme_cold: int64
#   heavy_precipitation: int64
#   tmax_bin: int64
#   tmin_bin: int64
#   prcp_category: object
#   temp_stress: int64
#   combined_extreme: int64
#   prcp_intensity: float64
#   has_precipitation: int64

# %% [markdown]
# ## Temporal Feature Engineering
# Enhance temporal features based on seasonal patterns observed in visualizations.

# %%
# Enhanced temporal features (only create if not already present)
if 'day' not in df_features.columns:
    df_features['day'] = df_features['date'].dt.day
if 'day_of_year' not in df_features.columns:
    df_features['day_of_year'] = df_features['date'].dt.dayofyear

# Season encoding (based on outage rate patterns)
season_mapping = {'winter': 0, 'spring': 1, 'summer': 2, 'fall': 3}
if 'season' in df_features.columns:
    df_features['season_encoded'] = df_features['season'].map(season_mapping)

print("Existing temporal features found:")
existing_temporal = ['year', 'month', 'day_of_week', 'season', 'outage_hour', 'day_name']
for feat in existing_temporal:
    if feat in df_features.columns:
        print(f"  {feat}: {df_features[feat].dtype}")

# High-risk seasons (based on visualization insights)
# Assuming summer/winter are higher risk based on temperature extremes
df_features['high_risk_season'] = df_features['season'].isin(['summer', 'winter']).astype(int)

# Weekend indicator (using existing day_of_week)
df_features['is_weekend'] = (df_features['day_of_week'] >= 5).astype(int)

# Month groupings based on seasonal patterns (using existing month)
df_features['month_group'] = pd.cut(
    df_features['month'], 
    bins=[0, 3, 6, 9, 12], 
    labels=['winter', 'spring', 'summer', 'fall'],
    include_lowest=True
)

# Cyclical encoding for temporal features (using existing columns)
df_features['month_sin'] = np.sin(2 * np.pi * df_features['month'] / 12)
df_features['month_cos'] = np.cos(2 * np.pi * df_features['month'] / 12)
df_features['day_of_week_sin'] = np.sin(2 * np.pi * df_features['day_of_week'] / 7)
df_features['day_of_week_cos'] = np.cos(2 * np.pi * df_features['day_of_week'] / 7)

# Only create day_of_year cyclical if we have day_of_year
if 'day_of_year' in df_features.columns:
    df_features['day_of_year_sin'] = np.sin(2 * np.pi * df_features['day_of_year'] / 365)
    df_features['day_of_year_cos'] = np.cos(2 * np.pi * df_features['day_of_year'] / 365)

print("New temporal features created:")
new_temporal_features = ['season_encoded', 'high_risk_season', 'is_weekend', 'month_group',
                        'month_sin', 'month_cos', 'day_of_week_sin', 'day_of_week_cos',
                        'day_of_year_sin', 'day_of_year_cos']
for feat in new_temporal_features:
    if feat in df_features.columns:
        print(f"  {feat}: {df_features[feat].dtype}")
# Out:
# Existing temporal features found:
#   year: int64
#   month: int64
#   day_of_week: int64
#   season: object
#   outage_hour: float64
#   day_name: object
# New temporal features created:
#   season_encoded: float64
#   high_risk_season: int64
#   is_weekend: int64
#   month_group: category
#   month_sin: float64
#   month_cos: float64
#   day_of_week_sin: float64
#   day_of_week_cos: float64
#   day_of_year_sin: float64
#   day_of_year_cos: float64
# New temporal features created:
#   season_encoded: float64
#   high_risk_season: int64
#   is_weekend: int64
#   month_group: category
#   month_sin: float64
#   month_cos: float64
#   day_of_week_sin: float64
#   day_of_week_cos: float64
#   day_of_year_sin: float64
#   day_of_year_cos: float64

# %% [markdown]
# ## Geographic Feature Engineering
# Create features based on geographic risk patterns from state analysis.

# %%
# Geographic risk encoding
if 'state' in df_features.columns:
    # Calculate state-level outage rates
    state_risk = df_features.groupby('state')['outage_occurred'].mean().to_dict()
    df_features['state_risk_score'] = df_features['state'].map(state_risk)
    
    # High/medium/low risk state categories
    risk_terciles = pd.qcut(df_features['state_risk_score'], 3, labels=['low', 'medium', 'high'])
    df_features['state_risk_category'] = risk_terciles
    
    # Binary high-risk state indicator
    high_risk_threshold = df_features['state_risk_score'].quantile(0.75)
    df_features['high_risk_state'] = (df_features['state_risk_score'] >= high_risk_threshold).astype(int)
    
    # State encoding (for models that can handle categorical)
    le_state = LabelEncoder()
    df_features['state_encoded'] = le_state.fit_transform(df_features['state'])
    
    print(f"State risk scores calculated for {len(state_risk)} states")
    print(f"High-risk threshold: {high_risk_threshold:.4f}")

# Regional encoding (if available)
if 'region' in df_features.columns:
    region_risk = df_features.groupby('region')['outage_occurred'].mean().to_dict()
    df_features['region_risk_score'] = df_features['region'].map(region_risk)
    
    le_region = LabelEncoder()
    df_features['region_encoded'] = le_region.fit_transform(df_features['region'])
    
    print(f"Regional risk scores calculated for {len(region_risk)} regions")

print("Geographic features created:")
geographic_features = ['state_risk_score', 'state_risk_category', 'high_risk_state', 
                      'state_encoded', 'region_risk_score', 'region_encoded']
for feat in geographic_features:
    if feat in df_features.columns:
        print(f"  {feat}: {df_features[feat].dtype}")
# Out:
# State risk scores calculated for 43 states
# High-risk threshold: 0.6424
# Regional risk scores calculated for 5 regions
# Geographic features created:
#   state_risk_score: float64
#   state_risk_category: category
#   high_risk_state: int64
#   state_encoded: int64
#   region_risk_score: float64
#   region_encoded: int64
# Regional risk scores calculated for 5 regions
# Geographic features created:
#   state_risk_score: float64
#   state_risk_category: category
#   high_risk_state: int64
#   state_encoded: int64
#   region_risk_score: float64
#   region_encoded: int64

# %% [markdown]
# ## Feature Summary and Preparation
# Prepare all features for analysis and selection.

# %%
# Identify all engineered features
original_cols = ['fips_code', 'county', 'state', 'date', 'tmax', 'tmin', 'prcp', 'outage_occurred', 'customers_out', 'run_start_time']
# These are existing derived features from the integration notebook
existing_derived = ['year', 'month', 'day_of_week', 'day_name', 'season', 'outage_hour', 'region']

# Only count truly NEW engineered features
engineered_features = [col for col in df_features.columns if col not in original_cols + existing_derived]

print(f"Original raw features: {len(original_cols)}")
print(f"Existing derived features: {len(existing_derived)}")
print(f"NEW engineered features: {len(engineered_features)}")
print("\nNEW engineered features by category:")

# Categorize features
weather_eng = [f for f in engineered_features if any(w in f.lower() for w in ['temp', 'prcp', 'extreme', 'stress', 'weather'])]
temporal_eng = [f for f in engineered_features if any(t in f.lower() for t in ['year', 'month', 'day', 'season', 'weekend', 'sin', 'cos'])]
geographic_eng = [f for f in engineered_features if any(g in f.lower() for g in ['state', 'region', 'risk'])]
other_eng = [f for f in engineered_features if f not in weather_eng + temporal_eng + geographic_eng]

print(f"  Weather-based: {len(weather_eng)}")
print(f"  Temporal: {len(temporal_eng)}")
print(f"  Geographic: {len(geographic_eng)}")
print(f"  Other: {len(other_eng)}")

# Handle categorical variables for numerical analysis
df_numeric = df_features.copy()

# Encode categorical features
categorical_cols = df_numeric.select_dtypes(include=['object']).columns
categorical_cols = [col for col in categorical_cols if col not in ['county', 'state', 'region', 'date']]

for col in categorical_cols:
    if col in df_numeric.columns:
        le = LabelEncoder()
        df_numeric[col] = le.fit_transform(df_numeric[col].astype(str))

print(f"\nCategorical columns encoded: {list(categorical_cols)}")
print(f"Final dataset shape: {df_numeric.shape}")
# Out:
# Original raw features: 10
# Existing derived features: 7
# NEW engineered features: 30
#
# NEW engineered features by category:
#   Weather-based: 8
#   Temporal: 12
#   Geographic: 7
#   Other: 4
#
# Categorical columns encoded: ['run_start_time', 'day_name', 'season', 'prcp_category']
# Final dataset shape: (3976135, 47)
#
# Categorical columns encoded: ['run_start_time', 'day_name', 'season', 'prcp_category']
# Final dataset shape: (3976135, 47)

# %%
df_numeric.columns
# Out:
# Index(['fips_code', 'date', 'prcp', 'tmax', 'tmin', 'outage_occurred',
#        'customers_out', 'county', 'state', 'run_start_time', 'year', 'month',
#        'day_of_week', 'day_name', 'season', 'outage_hour', 'region',
#        'temp_range', 'temp_avg', 'extreme_hot', 'extreme_cold',
#        'heavy_precipitation', 'tmax_bin', 'tmin_bin', 'prcp_category',
#        'temp_stress', 'combined_extreme', 'prcp_intensity',
#        'has_precipitation', 'day', 'day_of_year', 'season_encoded',
#        'high_risk_season', 'is_weekend', 'month_group', 'month_sin',
#        'month_cos', 'day_of_week_sin', 'day_of_week_cos', 'day_of_year_sin',
#        'day_of_year_cos', 'state_risk_score', 'state_risk_category',
#        'high_risk_state', 'state_encoded', 'region_risk_score',
#        'region_encoded'],
#       dtype='object')

# %% [markdown]
# ## Feature Importance Analysis
# Analyze which features are most predictive of power outages.

# %%
# Prepare feature matrix and target (after debugging fixes)
exclude_cols = ['fips_code', 'county', 'state', 'region', 'date', 'outage_occurred', 'customers_out', 'run_start_time', 'day_name']
feature_cols = [col for col in df_numeric.columns if col not in exclude_cols]

# Handle problematic features before creating X
if 'outage_hour' in feature_cols:
    # outage_hour has many missing values - fill with a default like -1 or median of non-null values
    if 'outage_hour' in df_numeric.columns:
        df_numeric['outage_hour'] = df_numeric['outage_hour'].fillna(-1)  # -1 indicates "no outage time recorded"

# Fix season_encoded if it's all NaN
if 'season_encoded' in df_numeric.columns and df_numeric['season_encoded'].isnull().all():
    print("Fixing season_encoded mapping...")
    # Drop it for now if mapping completely failed
    feature_cols = [col for col in feature_cols if col != 'season_encoded']
    df_numeric = df_numeric.drop('season_encoded', axis=1)

X = df_numeric[feature_cols]
y = df_numeric['outage_occurred']

# Ensure ALL features in X are numeric - encode any remaining categorical features
print("Checking data types in feature matrix:")
non_numeric_features = []
for col in X.columns:
    if X[col].dtype == 'object' or X[col].dtype.name == 'category':
        non_numeric_features.append(col)
        print(f"  {col}: {X[col].dtype} - ENCODING")
        le = LabelEncoder()
        X[col] = le.fit_transform(X[col].astype(str))
    else:
        print(f"  {col}: {X[col].dtype} - OK")

if non_numeric_features:
    print(f"\nEncoded {len(non_numeric_features)} categorical features: {non_numeric_features}")
else:
    print("\nAll features are already numeric!")

# Check for missing values first
print("Checking for missing values in feature matrix:")
missing_counts = X.isnull().sum()
features_with_missing = missing_counts[missing_counts > 0]

if len(features_with_missing) > 0:
    print(f"Features with missing values:")
    for feature, count in features_with_missing.items():
        print(f"  {feature}: {count} missing ({count/len(X)*100:.2f}%)")
        print(f"    dtype: {X[feature].dtype}")
        if count < 10:  # Show sample of missing rows for small counts
            missing_rows = X[X[feature].isnull()].index[:5].tolist()
            print(f"    sample missing row indices: {missing_rows}")
        print()
else:
    print("No missing values found in feature matrix!")

print(f"Feature matrix shape: {X.shape}")
print(f"Features for analysis: {len(feature_cols)}")

# 1. Mutual Information
print("\nCalculating mutual information...")
mi_scores = mutual_info_classif(X, y, random_state=42)
mi_results = pd.DataFrame({
    'feature': feature_cols,
    'mutual_info': mi_scores
}).sort_values('mutual_info', ascending=False)

# 2. F-statistic (ANOVA)
print("Calculating F-statistics...")
f_scores, f_pvalues = f_classif(X, y)
f_results = pd.DataFrame({
    'feature': feature_cols,
    'f_score': f_scores,
    'f_pvalue': f_pvalues
}).sort_values('f_score', ascending=False)

# 3. Random Forest Feature Importance
print("Training Random Forest for feature importance...")
rf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
rf.fit(X, y)
rf_results = pd.DataFrame({
    'feature': feature_cols,
    'rf_importance': rf.feature_importances_
}).sort_values('rf_importance', ascending=False)

print("Feature importance analysis complete!")
# Out:
# Checking data types in feature matrix:
#   prcp: float64 - OK
#   tmax: float64 - OK
#   tmin: float64 - OK
#   year: int64 - OK
#   month: int64 - OK
#   day_of_week: int64 - OK
#   season: int64 - OK
#   outage_hour: float64 - OK
#   temp_range: float64 - OK
#   temp_avg: float64 - OK
#   extreme_hot: int64 - OK
#   extreme_cold: int64 - OK
#   heavy_precipitation: int64 - OK
#   tmax_bin: int64 - OK
#   tmin_bin: int64 - OK
#   prcp_category: int64 - OK
#   temp_stress: int64 - OK
#   combined_extreme: int64 - OK
#   prcp_intensity: float64 - OK
#   has_precipitation: int64 - OK
#   day: int32 - OK
#   day_of_year: int32 - OK
#   high_risk_season: int64 - OK
#   is_weekend: int64 - OK
#   month_group: category - ENCODING
#   month_sin: float64 - OK
#   month_cos: float64 - OK
#   day_of_week_sin: float64 - OK
#   day_of_week_cos: float64 - OK
#   day_of_year_sin: float64 - OK
#   day_of_year_cos: float64 - OK
#   state_risk_score: float64 - OK
# ...

# %%
# Combine all importance measures
importance_combined = mi_results.merge(f_results, on='feature').merge(rf_results, on='feature')

for col in ['mutual_info', 'f_score', 'rf_importance']:
    importance_combined[f'{col}_norm'] = (
        importance_combined[col] / importance_combined[col].max()
    )

importance_combined['composite_score'] = (
    importance_combined['mutual_info_norm'] + 
    importance_combined['f_score_norm'] + 
    importance_combined['rf_importance_norm']
) / 3

importance_combined = importance_combined.sort_values('composite_score', ascending=False)

print("Top 15 Features by Composite Importance Score:")
print("=" * 60)
top_features = importance_combined.head(15)
for idx, row in top_features.iterrows():
    print(f"{row['feature']:<25} | Score: {row['composite_score']:.3f} | "
          f"MI: {row['mutual_info']:.4f} | F: {row['f_score']:.1f} | RF: {row['rf_importance']:.4f}")
# Out:
# Top 15 Features by Composite Importance Score:
# ...
# outage_hour               | Score: 1.000 | MI: 0.7454 | F: 2430671.5 | RF: 0.8041
# year                      | Score: 0.284 | MI: 0.1924 | F: 1146549.8 | RF: 0.0992
# state_risk_score          | Score: 0.130 | MI: 0.0832 | F: 576790.9 | RF: 0.0341
# state_risk_category       | Score: 0.123 | MI: 0.2358 | F: 68502.0 | RF: 0.0208
# high_risk_state           | Score: 0.098 | MI: 0.1099 | F: 309774.6 | RF: 0.0149
# region_risk_score         | Score: 0.072 | MI: 0.1295 | F: 92411.6 | RF: 0.0033
# prcp_category             | Score: 0.071 | MI: 0.1591 | F: 55.6 | RF: 0.0001
# has_precipitation         | Score: 0.060 | MI: 0.1345 | F: 46.7 | RF: 0.0001
# tmax_bin                  | Score: 0.053 | MI: 0.1188 | F: 1111.7 | RF: 0.0003
# region_encoded            | Score: 0.052 | MI: 0.1154 | F: 854.0 | RF: 0.0017
# day_of_week_cos           | Score: 0.049 | MI: 0.1088 | F: 126.7 | RF: 0.0002
# ...

# %% [markdown]
# ## Feature Importance Visualization

# %%
# Visualize top features
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

top_n = 15

# Mutual Information
top_mi = mi_results.head(top_n)
axes[0,0].barh(range(len(top_mi)), top_mi['mutual_info'], color='skyblue')
axes[0,0].set_yticks(range(len(top_mi)))
axes[0,0].set_yticklabels(top_mi['feature'], fontsize=9)
axes[0,0].set_xlabel('Mutual Information Score')
axes[0,0].set_title('Top Features: Mutual Information')
axes[0,0].invert_yaxis()

# F-Statistic
top_f = f_results.head(top_n)
axes[0,1].barh(range(len(top_f)), top_f['f_score'], color='lightcoral')
axes[0,1].set_yticks(range(len(top_f)))
axes[0,1].set_yticklabels(top_f['feature'], fontsize=9)
axes[0,1].set_xlabel('F-Statistic Score')
axes[0,1].set_title('Top Features: F-Statistic (ANOVA)')
axes[0,1].invert_yaxis()

# Random Forest
top_rf = rf_results.head(top_n)
axes[1,0].barh(range(len(top_rf)), top_rf['rf_importance'], color='lightgreen')
axes[1,0].set_yticks(range(len(top_rf)))
axes[1,0].set_yticklabels(top_rf['feature'], fontsize=9)
axes[1,0].set_xlabel('Random Forest Importance')
axes[1,0].set_title('Top Features: Random Forest')
axes[1,0].invert_yaxis()

# Composite Score
top_composite = importance_combined.head(top_n)
axes[1,1].barh(range(len(top_composite)), top_composite['composite_score'], color='gold')
axes[1,1].set_yticks(range(len(top_composite)))
axes[1,1].set_yticklabels(top_composite['feature'], fontsize=9)
axes[1,1].set_xlabel('Composite Score')
axes[1,1].set_title('Top Features: Composite Score')
axes[1,1].invert_yaxis()

plt.tight_layout()
plt.savefig(output_dir / 'feature_importance_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Feature Selection
# Select the best features based on multiple criteria.

# %%
# Feature selection based on different criteria

# 1. Top K features by composite score
def select_top_k_features(k=20):
    return importance_combined.head(k)['feature'].tolist()

# 2. Features above threshold in composite score
def select_by_threshold(threshold=0.1):
    return importance_combined[importance_combined['composite_score'] >= threshold]['feature'].tolist()

# 3. Features that appear in top N for at least 2 methods
def select_consensus_features(top_n=20):
    top_mi_set = set(mi_results.head(top_n)['feature'])
    top_f_set = set(f_results.head(top_n)['feature'])
    top_rf_set = set(rf_results.head(top_n)['feature'])
    
    consensus_features = []
    all_features = top_mi_set | top_f_set | top_rf_set
    
    for feature in all_features:
        count = sum([feature in s for s in [top_mi_set, top_f_set, top_rf_set]])
        if count >= 2:  # Appears in at least 2 methods
            consensus_features.append(feature)
    
    return consensus_features

# Apply different selection strategies
selected_top20 = select_top_k_features(20)
selected_threshold = select_by_threshold(0.1)
selected_consensus = select_consensus_features(20)

print("Feature Selection Results:")
print("=" * 40)
print(f"Top 20 by composite score: {len(selected_top20)} features")
print(f"Above threshold (0.1): {len(selected_threshold)} features")
print(f"Consensus (2+ methods): {len(selected_consensus)} features")

# Find overlap between methods
overlap_all = set(selected_top20) & set(selected_threshold) & set(selected_consensus)
print(f"\nOverlap across all methods: {len(overlap_all)} features")

# Recommended feature set (consensus + top composite)
recommended_features = list(set(selected_consensus + selected_top20[:15]))
print(f"Recommended feature set: {len(recommended_features)} features")

print("\nRecommended Features:")
for i, feature in enumerate(recommended_features, 1):
    score = importance_combined[importance_combined['feature'] == feature]['composite_score'].iloc[0]
    print(f"{i:2d}. {feature:<25} (score: {score:.3f})")
# Out:
# Feature Selection Results:
# ...
# Top 20 by composite score: 20 features
# Above threshold (0.1): 4 features
# Consensus (2+ methods): 21 features
#
# Overlap across all methods: 4 features
# Recommended feature set: 25 features
#
# Recommended Features:
#  1. day_of_year_cos           (score: 0.002)
#  2. season                    (score: 0.047)
#  3. high_risk_state           (score: 0.098)
#  4. tmin                      (score: 0.002)
#  5. region_encoded            (score: 0.052)
#  6. state_risk_score          (score: 0.130)
#  7. temp_avg                  (score: 0.002)
#  8. is_weekend                (score: 0.040)
#  9. day_of_week_cos           (score: 0.049)
# 10. region_risk_score         (score: 0.072)
# 11. day_of_week_sin           (score: 0.032)
# 12. tmax_bin                  (score: 0.053)
# 13. state_risk_category       (score: 0.123)
# 14. tmin_bin                  (score: 0.049)
# 15. prcp_category             (score: 0.071)
# ...

# %% [markdown]
# ## Feature Categories Analysis
# Analyze which types of features are most important.

# %%
# Categorize all features
def categorize_feature(feature_name):
    feature_lower = feature_name.lower()
    
    if any(w in feature_lower for w in ['tmax', 'tmin', 'temp', 'prcp', 'precipitation', 'extreme', 'stress', 'weather']):
        return 'Weather'
    elif any(t in feature_lower for t in ['year', 'month', 'day', 'season', 'weekend', 'sin', 'cos']):
        return 'Temporal'
    elif any(g in feature_lower for g in ['state', 'region', 'risk']):
        return 'Geographic'
    else:
        return 'Other'

# Add category to importance results
importance_combined['category'] = importance_combined['feature'].apply(categorize_feature)

# Analyze by category
category_analysis = importance_combined.groupby('category').agg({
    'composite_score': ['count', 'mean', 'max'],
    'mutual_info': 'mean',
    'f_score': 'mean',
    'rf_importance': 'mean'
}).round(4)

category_analysis.columns = ['count', 'avg_composite', 'max_composite', 'avg_mi', 'avg_f', 'avg_rf']
category_analysis = category_analysis.sort_values('avg_composite', ascending=False)

print("Feature Category Analysis:")
print("=" * 50)
print(category_analysis)

# Top features by category
print("\nTop 5 Features by Category:")
print("=" * 30)
for category in category_analysis.index:
    top_in_category = importance_combined[
        importance_combined['category'] == category
    ].head(5)
    
    print(f"\n{category}:")
    for _, row in top_in_category.iterrows():
        print(f"  {row['feature']:<25} (score: {row['composite_score']:.3f})")
# Out:
# Feature Category Analysis:
# ...
#             count  avg_composite  max_composite  avg_mi         avg_f  avg_rf
# category
# Other           1         1.0000         1.0000  0.7454  2.430672e+06  0.8041
# Geographic      6         0.0861         0.1304  0.1266  1.753705e+05  0.0132
# Temporal       14         0.0449         0.2844  0.0629  8.384086e+04  0.0072
# Weather        15         0.0170         0.0712  0.0373  5.374966e+02  0.0006
#
# Top 5 Features by Category:
# ...
#
# Other:
#   outage_hour               (score: 1.000)
#
# Geographic:
#   state_risk_score          (score: 0.130)
#   state_risk_category       (score: 0.123)
#   high_risk_state           (score: 0.098)
#   region_risk_score         (score: 0.072)
#   region_encoded            (score: 0.052)
#
# Temporal:
#   year                      (score: 0.284)
#   day_of_week_cos           (score: 0.049)
#   month_group               (score: 0.048)
#   season                    (score: 0.047)
# ...

# %%
# Visualize category performance
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Average composite score by category
axes[0].bar(category_analysis.index, category_analysis['avg_composite'], 
           color=['skyblue', 'lightcoral', 'lightgreen', 'gold'])
axes[0].set_ylabel('Average Composite Score')
axes[0].set_title('Feature Importance by Category')
axes[0].tick_params(axis='x', rotation=45)

# Feature count by category
axes[1].bar(category_analysis.index, category_analysis['count'], 
           color=['skyblue', 'lightcoral', 'lightgreen', 'gold'])
axes[1].set_ylabel('Number of Features')
axes[1].set_title('Feature Count by Category')
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.savefig(output_dir / 'feature_categories_analysis.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Final Feature Set Recommendation
# Provide final recommendations for modeling.

# %%
# Create final feature set recommendations
print("FEATURE ENGINEERING & SELECTION SUMMARY")
print("=" * 50)

print(f"\nTotal features engineered: {len(engineered_features)}")
print(f"Original features: {len(original_cols) - 1}")  # Exclude target
print(f"Final feature candidates: {len(feature_cols)}")

# Recommended sets for different model types
essential_features = importance_combined.head(10)['feature'].tolist()
extended_features = importance_combined.head(20)['feature'].tolist()
comprehensive_features = recommended_features

print(f"\nRecommended Feature Sets:")
print(f"  Essential (top 10): {len(essential_features)} features")
print(f"  Extended (top 20): {len(extended_features)} features")
print(f"  Comprehensive (consensus): {len(comprehensive_features)} features")

# Feature engineering insights
print(f"\nKey Engineering Insights:")
top_engineered = [f for f in essential_features if f in engineered_features]
print(f"  {len(top_engineered)}/{len(essential_features)} top features are engineered")

# Category representation in top features
top_10_categories = importance_combined.head(10)['category'].value_counts()
print(f"\nTop 10 Feature Categories:")
for category, count in top_10_categories.items():
    print(f"  {category}: {count} features")

# Save feature sets
feature_sets = {
    'essential': essential_features,
    'extended': extended_features,
    'comprehensive': comprehensive_features,
    'all_engineered': engineered_features
}

# Save to CSV for easy access
importance_combined.to_csv(output_dir / 'feature_importance_analysis.csv', index=False)

print(f"\nResults saved to: {output_dir}")
print("\nReady for model development!")

# Display final recommendations
print("\n" + "="*60)
print("FINAL FEATURE RECOMMENDATIONS")
print("="*60)
print("\nESSENTIAL FEATURES (Top 10):")
for i, feature in enumerate(essential_features, 1):
    category = importance_combined[importance_combined['feature'] == feature]['category'].iloc[0]
    score = importance_combined[importance_combined['feature'] == feature]['composite_score'].iloc[0]
    print(f"{i:2d}. {feature:<25} | {category:<10} | Score: {score:.3f}")
# Out:
# FEATURE ENGINEERING & SELECTION SUMMARY
# ...
#
# Total features engineered: 30
# Original features: 9
# Final feature candidates: 37
#
# Recommended Feature Sets:
#   Essential (top 10): 10 features
#   Extended (top 20): 20 features
#   Comprehensive (consensus): 25 features
#
# Key Engineering Insights:
#   8/10 top features are engineered
#
# Top 10 Feature Categories:
#   Geographic: 5 features
#   Weather: 3 features
#   Other: 1 features
#   Temporal: 1 features
#
# Results saved to: ../../notebooks/outputs/milestone_1/feature_analysis
#
# Ready for model development!
#
# ...
# FINAL FEATURE RECOMMENDATIONS
# ...
#
# ESSENTIAL FEATURES (Top 10):
#  1. outage_hour               | Other      | Score: 1.000
#  2. year                      | Temporal   | Score: 0.284
#  3. state_risk_score          | Geographic | Score: 0.130
#  4. state_risk_category       | Geographic | Score: 0.123
#  5. high_risk_state           | Geographic | Score: 0.098
# ...
